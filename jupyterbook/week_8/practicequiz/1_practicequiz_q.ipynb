# %% [markdown]
# $$
# y=\frac{2}{1}x+16\ \left\{-11\le x\le-9\right\}
# $$
#
# $$
# y=\frac{1}{2\ }\left|x+7\right|-8\ \left\{-11\le x\le-5\right\}
# $$
#
# $$
# y=-1x+\left(-12\right)\ \left\{-7\le x\le-5\right\}
# $$
#
# $$
# y=\frac{1}{2}x+1.5\ \left\{-7\le x\le-5\right\}
# $$
#
# $$
# y-\left(-4\right)=\frac{1}{2}\left(x-\left(-5\right)\right)\ \left\{-7\le x\le-5\right\}
# $$
#
# $$
# y-\left(-4\right)=-3\left(x-\left(-5\right)\right)\left\{-5\le x\le-4\right\}
# $$
#
# $$
# y-\left(-7\right)=\frac{2}{1}\left(x-\left(-4\right)\right)\left\{-4\le x\le-3\right\}
# $$
#
# $$
# x=-3\left\{-5\le y\le-3\right\}
# $$
#
# $$
# y-\left(-3\right)=\frac{1}{2}\left(x-\left(-3\right)\right)\ \left\{-3\le x\le-1\right\}
# $$
#
# $$
# y-\left(-2\right)=-1\left(x-\left(-1\right)\right)\ \left\{-1\le x\le0\right\}
# $$
#
# $$
# y-\left(-3\right)=1\left(x-0\right)\ \left\{-1\le x\le0\right\}
# $$
#
# $$
# y-\left(-4\right)=\frac{1}{2}\left(x-\left(-1\right)\right)\ \left\{-1\le x\le3\right\}
# $$
#
# $$
# x=3\left\{-2\le y\le-1\right\}
# $$
#
# $$
# y=1\left|x-4\right|-2\ \left\{3\le x\le7\right\}
# $$
#
# $$
# y-1=0\left(x-7\right)\ \left\{6\le x\le7\right\}
# $$
#
# $$
# y-1=1\left(x-6\right)\ \left\{6\le x\le10\right\}
# $$
#
# $$
# y-5=0\left(x-10\right)\ \left\{3\le x\le10\right\}
# $$
#
# $$
# y-5=3\left(x-3\right)\ \left\{3\le x\le4\right\}
# $$
#
# $$
# y-8=\frac{1}{3}\left(x-4\right)\ \left\{-2\le x\le4\right\}
# $$
#
# $$
# y-6=3\left(x-\left(-2\right)\right)\ \left\{-2\le x\le-1\right\}
# $$
#
# $$
# y-9=1\left(x-\left(-1\right)\right)\ \left\{-7\le x\le-1\right\}
# $$
#
# $$
# x=-7\ \left\{3\le y\le5\right\}
# $$
#
# $$
# y-5=2\left(x-\left(-7\right)\right)\ \left\{-11\le x\le-7\right\}
# $$
#
# $$
# y-\left(-3\right)=\frac{1}{2}\left(x-\left(-11\right)\right)\ \left\{-11\le x\le-9\right\}
# $$

# %%
# Import the necessary libraries
# numpy, matplotlib, division
# BEGIN SOLUTION
import matplotlib.pyplot as plt
import numpy as np
# END SOLUTION

# %%
""" # BEGIN TEST CONFIG
points: 2
hidden: false
success_message: "Success: All required libraries and typing imports are correctly imported!"
failure_message: "Failed: One or more required libraries or typing imports are missing."
log_variables: ["imported_modules"]
"""  # END TEST CONFIG

import sys

# Extract imported modules
imported_modules = set(sys.modules.keys())

# Define required libraries
required_libraries = {"matplotlib.pyplot", "numpy", "math"}

# Verify all required libraries are imported
missing_libraries = required_libraries - imported_modules

assert (
    not missing_libraries
), f"Missing imports: {missing_libraries}. Ensure all required libraries are imported."

# %%
# Predefined functions
def eq1(x):
    return (2/1) * x + 16

def eq2(x):
    return (1/2) * np.abs(x + 7) - 8

def eq3(x):
    return -1 * x - 12

def eq4(x):
    return (1/2) * x + 1.5

def eq5(x):
    return (-4) + (1/2) * (x + 5)

def eq6(x):
    return (-4) + (-3) * (x + 5)

def eq7(x):
    return (-7) + (2/1) * (x + 4)

def eq8(y):
    return np.full_like(y, -3)

def eq9(x):
    return (-3) + (1/2) * (x + 3)

def eq10(x):
    return (-2) - (x + 1)

def eq11(x):
    return (-3) + 1 * (x - 0)

def eq12(x):
    return (-4) + (1/2) * (x + 1)

def eq13(y):
    return np.full_like(y, 3)

def eq14(x):
    return 1 * np.abs(x - 4) - 2

def eq15(x):
    return np.full_like(x, 1)

def eq16(x):
    return 1 + 1 * (x - 6)

def eq17(x):
    return np.full_like(x, 5)

def eq18(x):
    return 5 + 3 * (x - 3)

def eq19(x):
    return 8 + (1/3) * (x - 4)

def eq20(x):
    return 6 + 3 * (x + 2)

def eq21(x):
    return 9 + 1 * (x + 1)

def eq22(y):
    return np.full_like(y, -7)

def eq23(x):
    return 5 + 2 * (x + 7)

def eq24(x):
    return (-3) + (1/2) * (x + 11)

# PreDefine ranges for x and y
ranges_x = [
    np.linspace(-11, -9, 100), np.linspace(-11, -5, 100), np.linspace(-7, -5, 100),
    np.linspace(-7, -5, 100), np.linspace(-7, -5, 100), np.linspace(-5, -4, 100),
    np.linspace(-4, -3, 100), np.linspace(-3, -1, 100), np.linspace(-1, 0, 100),
    np.linspace(-1, 0, 100), np.linspace(-1, 3, 100), np.linspace(3, 7, 100),
    np.linspace(6, 7, 100), np.linspace(6, 10, 100), np.linspace(3, 10, 100),
    np.linspace(3, 4, 100), np.linspace(-2, 4, 100), np.linspace(-2, -1, 100),
    np.linspace(-7, -1, 100), np.linspace(-11, -7, 100), np.linspace(-11, -9, 100)
]
# Functions corresponding to ranges
functions_x = [
    eq1, eq2, eq3, eq4, eq5, eq6, eq7, eq9, eq10, eq11, eq12, eq14, eq15,
    eq16, eq17, eq18, eq19, eq20, eq21, eq23, eq24
]

# %%
# 8. y = -7 use np.full_like() to create an array of -7s
# BEGIN SOLUTION
def eq8(y):
    return np.full_like(y, -7)
# END SOLUTION

# 12. y = 3 use np.full_like() to create an array of 3s
# BEGIN SOLUTION
def eq13(y):
    return np.full_like(y, 3)
# END SOLUTION

# 22. y = -3 use np.full_like() to create an array of -3s
# BEGIN SOLUTION
def eq22(y):
    return np.full_like(y, -3)
# END SOLUTION

# %%
# Define ranges for x and y as ranges_y for the vertical lines to plot the equations y = -3, y = 3, y = -7 and 
# x = -5, x = -2, x = 3 using np.linspace() function with 100 points between the given range as np.linspace(start, end, 100)
# BEGIN SOLUTION 
ranges_y = [
    np.linspace(3, 5, 100), np.linspace(-2, -1, 100), np.linspace(-3, -5, 100)
]
# END SOLUTION
# Make a list of functions corresponding to ranges_y for the vertical lines
# BEGIN SOLUTION
functions_y = [eq8, eq13, eq22]
# END SOLUTION

# Initialize the plot with figure size 10, 6 using plt.figure() function
# BEGIN SOLUTION
plt.figure(figsize=(10, 6))
# END SOLUTION


# Plot x-based functions
for func, x_range in zip(functions_x, ranges_x):
    plt.plot(x_range, func(x_range), 'g', linewidth=2)


# Plot the equations y-based functions (vertical lines) using plt.plot() with blue color 'b' and linewidth 2
# using a for loop to iterate over the functions_y and ranges_y using zip() function to combine them
# BEGIN SOLUTION
for func, y_range in zip(functions_y, ranges_y):
    plt.plot(func(y_range), y_range, 'b', linewidth=2)
# END SOLUTION


# Set up plot appearance
# Set the x-axis label using plt.xlabel() function
# Set the y-axis label using plt.ylabel() function
# Set the title using plt.title() function
# Set the grid using plt.grid() function
# Show the plot using plt.show() function
# Set axhline and axvline using plt.axhline() and plt.axvline() functions to draw horizontal and vertical lines
# Set the color of the lines as gray using color='gray'
# Set the linestyle as dashed using linestyle='dashed'
# Set the linewidth as 1 using linewidth=1
# BEGIN SOLUTION 
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.title("Graph of Multiple Equations making Eagles Logo")
plt.axhline(0, color='gray', linestyle='dashed', linewidth=1)
plt.axvline(0, color='gray', linestyle='dashed', linewidth=1)
plt.grid()
plt.show()
# END SOLUTION

# %%
""" # BEGIN TEST CONFIG
points: 2
hidden: false
success_message: "Success: `eq2()` handles absolute values correctly!"
failure_message: "Failed: `eq2()` does not handle absolute values correctly."
log_variables: ["eq2_edge_cases"]
"""  # END TEST CONFIG

eq2_edge_cases = [eq2(x) for x in [-11, -7, -5]]
condition = all(isinstance(val, float) for val in eq2_edge_cases)
assert condition

# %%
""" # BEGIN TEST CONFIG
points: 2
hidden: false
success_message: "Success: `eq3()` handles negative slope correctly!"
failure_message: "Failed: `eq3()` does not handle negative slope correctly."
log_variables: ["eq3_edge_cases"]
"""  # END TEST CONFIG

eq3_edge_cases = [eq3(x) for x in [-7, -6, -5]]
condition = all(isinstance(val, float) for val in eq3_edge_cases)
assert condition

# %%
""" # BEGIN TEST CONFIG
points: 2
hidden: false
success_message: "Success: `eq8()` correctly returns constant x values!"
failure_message: "Failed: `eq8()` does not return constant x values correctly."
log_variables: ["eq8_edge_cases"]
"""  # END TEST CONFIG

eq8_edge_cases = [eq8(y) for y in [-5, -4, -3]]
condition = all(val == -3 for val in eq8_edge_cases)
assert condition

# %%
""" # BEGIN TEST CONFIG
points: 2
hidden: false
success_message: "Success: `eq13()` correctly returns constant x values!"
failure_message: "Failed: `eq13()` does not return constant x values correctly."
log_variables: ["eq13_edge_cases"]
"""  # END TEST CONFIG

eq13_edge_cases = [eq13(y) for y in [-2, -1]]
condition = all(val == 3 for val in eq13_edge_cases)
assert condition

# %%
""" # BEGIN TEST CONFIG
points: 2
hidden: false
success_message: "Success: `eq22()` correctly returns constant x values!"
failure_message: "Failed: `eq22()` does not return constant x values correctly."
log_variables: ["eq22_edge_cases"]
"""  # END TEST CONFIG

eq22_edge_cases = [eq22(y) for y in [3, 4, 5]]
condition = all(val == -7 for val in eq22_edge_cases)
assert condition

# %%
""" # BEGIN TEST CONFIG
points: 2
hidden: false
success_message: "Success: `eq17()` correctly returns a constant y!"
failure_message: "Failed: `eq17()` does not return a constant y correctly."
log_variables: ["eq17_edge_cases"]
"""  # END TEST CONFIG

eq17_edge_cases = [eq17(x) for x in [3, 6, 10]]
condition = all(val == 5 for val in eq17_edge_cases)
assert condition
